# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
from sklearn.manifold import TSNE
import pickle
# from Bio.Cluster import kcluster
import os
import numpy as np
import yaml
import os
import pandas
from collections import Counter
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import sys
import seaborn as sns
# import pyclustering
import matplotlib.pylab as plt
import seaborn as sb

plt.rcParams['figure.dpi'] = 400

from shutil import copyfile
import matplotlib as plt
# ------- SERVER EXTENSIONS ---------
lib =  r'/srv01/technion/shitay/Code/classifying_response_to_immunotherapy/utilities/droplet_dataset'
lib2 = r'/srv01/technion/shitay/Code/classifying_response_to_immunotherapy/utilities'
lib3 = r'/srv01/technion/shitay/Code/classifying_response_to_immunotherapy/data_analysis'
lib4 = r'/srv01/technion/shitay/Code/classifying_response_to_immunotherapy'
lib5 = r'/srv01/technion/shitay/Code/classifying_response_to_immunotherapy/scripts'
import sys
sys.path.append(lib)
sys.path.append(lib2)
sys.path.append(lib3)
sys.path.append(lib4)
sys.path.append(lib5)
# ------- SERVER EXTENSIONS ---------

# %% [markdown]
# # Different variances

# %%
variance = 6
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=myel)
# Out:
# Variance 6
# Counts shape (89024, 4)
# Text(0.5, 1.0, 'Variance > 6, 4 genes')

# %%
variance = 1
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 1
# Counts shape (89024, 1087)
# Text(0.5, 1.0, 'Variance > 1, 1087 genes')

# %%
variance = 0.75
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.75
# Counts shape (89024, 1537)
# Text(0.5, 1.0, 'Variance > 0.75, 1537 genes')

# %%
variance = 0.5
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.5
# Counts shape (89024, 2558)
# Text(0.5, 1.0, 'Variance > 0.5, 2558 genes')

# %%
variance = 0.325
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.325
# Counts shape (89024, 3948)
# Text(0.5, 1.0, 'Variance > 0.325, 3948 genes')

# %%
variance = 0.315
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.315
# Counts shape (89024, 4074)
# Text(0.5, 1.0, 'Variance > 0.315, 4074 genes')

# %%
variance = 0.25
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.25
# Counts shape (89024, 5004)
# Text(0.5, 1.0, 'Variance > 0.25, 5004 genes')

# %% [markdown]
# # T cells vs. B cells

# %%
variance = 0.315
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/immune_TSNE_embedded_var{variance}.pkl'

cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"Variance > {variance}, {filtered_cells.counts.shape[1]} genes", size=24)
# Out:
# Variance 0.315
# Counts shape (89024, 4074)
# Text(0.5, 1.0, 'Variance > 0.315, 4074 genes')

# %% [markdown]
# # Cell type statistics

# %%
from utilities.general_helpers import flatten_list
from collections import Counter
cohort_path = r'/storage/md_keren/shitay/Data/droplet_seq/cohort/cohort.pkl'

cohort = pickle.load(open(cohort_path, 'rb'))
immune_cohort = cohort.filter_cells_by_property('is_immune', True)

Counter(flatten_list(immune_cohort.cells_information.getattr('cell_type_list')))
# Out:
# Counter({'T cells': 49737,
#          'Immune_general': 83266,
#          'myeloid cells_general_mature': 3716,
#          'Neutrophils': 15524,
#          'CD8 Cytotoxic T cells': 25906,
#          'Exhausted T cells': 16550,
#          'Regulatory T cells': 795,
#          'Monocyte_mature': 4031,
#          'B cells': 6527,
#          'Activated T cells': 1313,
#          'Granolocytes': 2639,
#          'CD4 helper T cells': 5856,
#          'cDCs_dendritic_cells': 2594,
#          'Memory CD4 T cells': 288,
#          'Monocyte_immature': 144,
#          'myeloid cells_general_immature': 86,
#          'NKT cells': 2138,
#          'Regulatory CD4 T cells': 482,
#          'Macrophage_mature': 2598,
#          'Memory T cells': 451,
#          'NK cells': 595,
#          'Macrophage_immature': 90,
#          'Memory CD8 T cells': 262,
#          'pDCs': 98,
#          'Regulatory CD4_CD8 T cells': 42,
#          'Memory CD4_CD8 T cells': 16,
#          'Regulatory CD8 T cells': 66,
#          'Stem_like T cells': 1})

# %% [markdown]
# # UMAP

# %%
COHORT_PATH = r'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
cohort = pickle.load(open(COHORT_PATH, 'rb'))
path = r'/storage/md_keren/shitay/outputs/UMAP/UMAP_cohort_immune_o.315var.pkl'
cells_embedded = pickle.load(open(path, 'rb'))
df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
cell_type = 'B cells'
# df[cell_type] = cohort.get_myeloid_lymphoid_map()[1] #
df[cell_type] = [cell_type in vv for vv in cohort.cells_information.getattr('cell_type_list')]
lm = sns.scatterplot(x="X", y="Y",
              hue=cell_type,
              data=df)
plt.pyplot.title(f"{cell_type}", size=24)
# plt.pyplot.title(f"Myeloid vs. Lymphoid", size=24)
# Out:
# Text(0.5, 1.0, 'B cells')

# %% [markdown]
# # Distribution of gene expression values after normalization
# taking imunne cells, filter variance=1 and present kog distribution

# %%
variance = 1
print(f"Variance {variance}")
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var{variance}.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
print(f'Counts shape {filtered_cells.counts.shape}')
a = np.round(np.ndarray.flatten(filtered_cells.counts))
bb = dict(Counter(a))

plt.pyplot.scatter(list(bb.keys()), np.log(list(bb.values())))
# plt.pyplot.scatter(list(bb.keys()), (list(bb.values())))
# Out:
# Variance 1
# Counts shape (89024, 1087)

# %%
c_path = r'/storage/md_keren/shitay/Data/droplet_seq/cohort/cohort.pkl'
cohort = pickle.load(open(c_path, 'rb'))
rr = Counter(np.ndarray.flatten(np.round(cohort.counts)))
print(rr)
np.round(np.array(list(rr.values()))/sum(list(rr.values())), 3)
# Out:
# Counter({0.0: 7067840640, 1.0: 151777134, 2.0: 98979319, 3.0: 54698886, 4.0: 23301535, 5.0: 9500831, 6.0: 5625347, 7.0: 2255209, 8.0: 544145, 9.0: 91201, 10.0: 15839, 11.0: 2457, 12.0: 425, 13.0: 224})
# array([0.013, 0.953, 0.02 , 0.007, 0.001, 0.003, 0.001, 0.   , 0.   ,
#        0.   , 0.   , 0.   , 0.   , 0.   ])

# %% [markdown]
# # Debug

# %%
perplexity = 10.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 30.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 50.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 70.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 90.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 110.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 130.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
perplexity = 150.0
TSNE_path = fr'/storage/md_keren/shitay/outputs/TSNE/perplexity/immune_TSNE_embedded_var0.315_perplexity{perplexity}.pkl'
filtered_cells_path = fr'/storage/md_keren/shitay/outputs/variance_filtered/immune_cells_var0.315.pkl'
filtered_cells = pickle.load(open(filtered_cells_path, 'rb'))
cells_embedded = pickle.load(open(TSNE_path, 'rb'))
# plt.pyplot.scatter(cells_embedded[:,0], cells_embedded[:,1], c=filtered_cells.get_myeloid_lymphoid_map()[0])

df = pd.DataFrame(cells_embedded, columns=['X', 'Y'])
df["cell type"] = filtered_cells.get_myeloid_lymphoid_map()[1]
lm = sns.scatterplot(x="X", y="Y",
              hue="cell type",
              data=df)
plt.pyplot.title(f"perplexity - {perplexity}", size=24);

# %%
df
# Out:
#                X          Y cell type
# 0      24.045540 -31.852228  lymphoid
# 1      25.427656 -17.508474   myeloid
# 2       4.659225 -25.245810  lymphoid
# 3      11.444803   0.020181   Nothing
# 4      31.355183  15.851969   Nothing
# 5      10.056245  38.692505  lymphoid
# 6     -27.957083  11.876464   Nothing
# 7       7.888683 -23.782892   myeloid
# 8       7.829386  29.758961   Nothing
# 9      10.733444  -0.206081  lymphoid
# 10     -2.566096 -29.222630   myeloid
# 11      2.941169  -6.572647  lymphoid
# 12      8.121806 -11.341563  lymphoid
# 13     -2.397199  21.206989  lymphoid
# 14     13.215281   7.191019  lymphoid
# 15     -7.102196   6.852880   Nothing
# 16    -11.834822 -30.691744   myeloid
# 17    -27.775600  11.562164   Nothing
# 18     13.573564  -1.918354  lymphoid
# 19      2.203080  25.503450  lymphoid
# 20    -28.139408  11.420887   myeloid
# 21     11.626948   0.045782  lymphoid
# 22     29.877527  -3.587404  lymphoid
# 23    -27.902571   5.385468   myeloid
# 24      1.786765  -4.980515  lymphoid
# 25      2.810451  -2.315639  lymphoid
# 26    -29.165209   3.902807   Nothing
# 27    -12.497265  -0.805352  lymphoid
# 28     10.511174  37.224274  lymphoid
# 29     -4.161894   0.691746  lymphoid
# ...          ...        ...       ...
# 88994 -19.305258 -22.875071   Nothing
# 88995 -19.445879 -22.709146   myeloid
# 88996  21.740557  23.693275   myeloid
# 88997  -4.584747  -9.716690   Nothing
# 88998  10.569798   5.626362   Nothing
# 88999  -6.688779 -29.863688   myeloid
# 89000  -9.339788  -0.920169  lymphoid
# 89001   7.390286  10.626173  lymphoid
# 89002   4.067268  31.164619  lymphoid
# 89003  -5.866174  -0.688671  lymphoid
# 89004  -3.418962  -2.202527  lymphoid
# 89005 -15.575766 -21.204140   myeloid
# 89006  -2.138103   7.169801  lymphoid
# 89007 -15.590464 -21.119913   myeloid
# 89008  17.231310  30.599253   Nothing
# 89009  10.936940  -1.732881   Nothing
# 89010  31.579878  -2.768220  lymphoid
# 89011  -8.378216 -19.680458   myeloid
# 89012  11.078943  -2.397229  lymphoid
# 89013  15.258002  32.481003   Nothing
# 89014   4.886433   0.940853  lymphoid
# 89015 -15.592339 -21.137121   Nothing
# 89016  -7.175428  -4.980005  lymphoid
# 89017  29.226276   6.646696  lymphoid
# 89018  12.861605  -2.618168  lymphoid
# 89019  -7.798495 -19.959698   Nothing
# 89020  -2.407868   7.113625   Nothing
# 89021 -13.000206  30.288872  lymphoid
# 89022   9.890446 -12.142151   myeloid
# 89023  -2.865439  -2.626118  lymphoid
#
# [89024 rows x 3 columns]
