# %%
import scanpy as sc
from  os.path import join
import sys
import os
lib = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\python_playground\classifying-response-to-immunotherapy\utilities\droplet_dataset'
lib2 = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\python_playground\classifying-response-to-immunotherapy\utilities'
lib3 = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\python_playground\classifying-response-to-immunotherapy\data_analysis'
lib4 = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\python_playground\classifying-response-to-immunotherapy'
lib5 = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\python_playground\classifying-response-to-immunotherapy\scripts'
sys.path.append(lib)
sys.path.append(lib2)
sys.path.append(lib3)
sys.path.append(lib4)
sys.path.append(lib5)
import os
from os.path import join
import sklearn
# from droplet_dataset import *
# from utilities import *
from matplotlib import pyplot
import numpy as np
import scipy
import pickle
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import random
from scipy.stats import pearsonr
from matplotlib.pyplot import figure
from termcolor import colored
import tables
from collections import Counter

# %%
dataset_path = r'C:\Users\KerenYlab\Desktop\Technion studies\Keren laboratory\Data\droplet_seq\DEBUG\1000_rand_cells.pkl'
cohort = pickle.load(open(dataset_path, 'rb'))

# %%
# test_train_split(cohort)

# %%
ann_cohort
# Out:
# AnnData object with n_obs × n_vars = 32738 × 1000
#     obs: 'gene', 'feature'
#     var: 'sample', 'barcode', 'cell_type_list', 'conflict_related_cell_types', 'is_apoptosis', 'is_immune', 'is_cancer', 'cancer_immune_conflict', 'is_doublet', 'is_lymphoid', 'is_myeloid', 'is_CelBender_empty', 'is_stromal', 'should_be_removed', 'is_epithelial', 'comment'

# %%
ann_cohort[ann_cohort.obs['is_immune']].obs
# Out:
#     sample             barcode  \
# 6     M100  CTCGAGGTCCGAAGAG-1
# 13    M100  TGAGCCGCAGGAACGT-1
# 21    M101  CGTAGCGCATAAGACA-1
# 24    M101  CTCTACGGTACCAGTT-1
# 26    M101  CTGCTGTTCGCCAAAT-1
# ..     ...                 ...
# 991    M99  GTCATTTAGCAGATCG-1
# 992    M99  GTTACAGCAGCTATTG-1
# 993    M99  TCAGCAAGTTCCTCCA-1
# 997    M99  TGCGTGGAGTGAACAT-1
# 999    M99  TTGCCGTTCACTTCAT-1
#
#                                         cell_type_list  \
# 6                                     [Immune_general]
# 13                           [T cells, Immune_general]
# 21    [T cells, CD8 Cytotoxic T cells, Immune_general]
# 24   [Neutrophils, cDCs_dendritic_cells, Immune_gen...
# 26   [T cells, Exhausted T cells, CD8 Cytotoxic T c...
# ..                                                 ...
# 991   [T cells, CD8 Cytotoxic T cells, Immune_general]
# 992      [T cells, CD4 helper T cells, Immune_general]
# 993                                   [Immune_general]
# ...

# %%
ann_cohort = cohort.convert_to_AnnData()

# %%
ann_cohort[['T cells' in l for l in ann_cohort.obs['cell_type_list'].tolist()]].obs
# Out:
#     sample             barcode  \
# 13    M100  TGAGCCGCAGGAACGT-1
# 21    M101  CGTAGCGCATAAGACA-1
# 26    M101  CTGCTGTTCGCCAAAT-1
# 76    M102  GCGACCAGTAGGACAC-1
# 133   M105  ACCAGTACACCACGTG-1
# ..     ...                 ...
# 990    M99  GCTGCGAAGCAATCTC-1
# 991    M99  GTCATTTAGCAGATCG-1
# 992    M99  GTTACAGCAGCTATTG-1
# 997    M99  TGCGTGGAGTGAACAT-1
# 999    M99  TTGCCGTTCACTTCAT-1
#
#                                         cell_type_list  \
# 13                           [T cells, Immune_general]
# 21    [T cells, CD8 Cytotoxic T cells, Immune_general]
# 26   [T cells, Exhausted T cells, CD8 Cytotoxic T c...
# 76                           [Immune_general, T cells]
# 133                          [T cells, Immune_general]
# ..                                                 ...
# 990   [T cells, CD8 Cytotoxic T cells, Immune_general]
# 991   [T cells, CD8 Cytotoxic T cells, Immune_general]
# 992      [T cells, CD4 helper T cells, Immune_general]
# ...

# %%
df = ann_cohort.cohort.obs['cell_type_list']

# %%
df.isin([['T cells', 'CD8 Cytotoxic T cells', 'Immune_general']])
ann_cohort[['T cells' in l for l in df.tolist()]].cohort.obs
# Out:
#     sample             barcode  \
# 13    M100  TGAGCCGCAGGAACGT-1
# 21    M101  CGTAGCGCATAAGACA-1
# 26    M101  CTGCTGTTCGCCAAAT-1
# 76    M102  GCGACCAGTAGGACAC-1
# 133   M105  ACCAGTACACCACGTG-1
# ..     ...                 ...
# 990    M99  GCTGCGAAGCAATCTC-1
# 991    M99  GTCATTTAGCAGATCG-1
# 992    M99  GTTACAGCAGCTATTG-1
# 997    M99  TGCGTGGAGTGAACAT-1
# 999    M99  TTGCCGTTCACTTCAT-1
#
#                                         cell_type_list  \
# 13                           [T cells, Immune_general]
# 21    [T cells, CD8 Cytotoxic T cells, Immune_general]
# 26   [T cells, Exhausted T cells, CD8 Cytotoxic T c...
# 76                           [Immune_general, T cells]
# 133                          [T cells, Immune_general]
# ..                                                 ...
# 990   [T cells, CD8 Cytotoxic T cells, Immune_general]
# 991   [T cells, CD8 Cytotoxic T cells, Immune_general]
# 992      [T cells, CD4 helper T cells, Immune_general]
# ...

# %%
DL = Droplet_data_manager(cohort)

# %%
# train_patient_set, test_patient_set = DL._train_test_patient_split_by_response()
X_train, X_test, y_train, y_test = DL.train_test_split(p_test_size=0.1, shuffle=True, verbose=False)

# %%
cohort.cells_information.cells_information_list[0].__dict__
cohort.cells_information.getattr('cell_type_list')
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Immune_general'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['T cells', 'Immune_general'],
#  [],
#  [],
#  ['Immune_general'],
#  ['Granolocytes'],
#  [],
#  [],
#  [],
#  ['T cells', 'CD8 Cytotoxic T cells', 'Immune_general'],
#  [],
#  [],
#  ['Neutrophils', 'cDCs_dendritic_cells', 'Immune_general'],
#  ['Immune_general'],
#  ['T cells', 'Exhausted T cells', 'CD8 Cytotoxic T cells', 'Immune_general'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Immune_general', 'T cells'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
l = [111, 7, 56, 700, 89]

def no_5_7(l):
    return [x if (not ('5' in str(x)) and not ('7' in str(x)))  else 0 for x in l]
no_5_7(l)
# Out:
# [111, 0, 0, 0, 89]
